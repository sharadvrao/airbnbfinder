# %%
from random import randint

# %%
import time

# %%
from selenium import webdriver
import selenium
import time
from bs4 import BeautifulSoup
import requests

# %%
def get_seattle_urls(main_url='https://hotpads.com/seattle-wa/apartments-for-rent'):
    seattle_page_urls = []
    for page_num in range(1, 105):
        if page_num == 1:
            seattle_page_urls.append(main_url)
        else:
            seattle_page_urls.append(main_url + f'?page={page_num}')
    return seattle_page_urls

# %%
browser = webdriver.Firefox()

# %%
def get_listing_urls(seattle_page_urls):
    full_links = []
    for page in seattle_page_urls:
        potential_links = []
        browser.get(page)
        time.sleep(20)
        current_page_source = browser.page_source        
        soup = BeautifulSoup(current_page_source, 'html.parser')
        for link in soup.find_all('a', href=True):
            potential_links.append(link['href'])
        for each_link in potential_links:
            if each_link.endswith('pad'):
                 full_links.append('https://hotpads.com' + each_link)
        time.sleep(randint(60,120))
    return set(full_links)

# %%
seattle_page_urls = get_seattle_urls()

# %%
all_the_links = get_listing_urls(seattle_page_urls)

# %%
len(all_the_links) #didn't get as many links as expected
# Out:
# 1739

# %%
all_the_links
# Out:
# {'https://hotpads.com/509-19th-avenue-seattle-wa-98122-1t6e764/pad',
#  'https://hotpads.com/evolve-seattle-wa-98122-ttmfks/pad',
#  'https://hotpads.com/301-belmont-ave-e-seattle-wa-98102-1n4gwmy/a/pad',
#  'https://hotpads.com/2300-elliott-seattle-wa-98121-skf9tk/pad',
#  'https://hotpads.com/seattle-wa-98115-1n4k0qj/pad',
#  'https://hotpads.com/502-bellevue-ave-e-seattle-wa-98102-ss4ptf/104/pad',
#  'https://hotpads.com/10044-65th-ave-s-seattle-wa-98178-1n4pn5b/pad',
#  'https://hotpads.com/1-bed-685-sqft-1470-seattle-wa-98122-tutcdb/pad',
#  'https://hotpads.com/oneone6-seattle-wa-98102-tux8un/pad',
#  'https://hotpads.com/capitol-hill-park-seattle-wa-98102-sku9dg/pad',
#  'https://hotpads.com/535-n-74th-st-seattle-wa-98103-sxyb6k/pad',
#  'https://hotpads.com/ava-belltown-seattle-wa-98121-skhr63/pad',
#  'https://hotpads.com/6814-28th-ave-nw-seattle-wa-98117-w08n8e/pad',
#  'https://hotpads.com/isherwood-apartments-seattle-wa-98103-tutd8h/pad',
# ...

# %%
with open('links.txt', 'w') as file:  
    for link_string in all_the_links:
        file.write('%s\n' % link_string)

# %%
file.close()

# %%
browser.get('https://hotpads.com/clearwater-apartments-seattle-wa-98122-skzcev/pad')

# %%
current_page_source = browser.page_source

# %%
current_page_source
# Out:
# '<html><head lang="en"><style type="text/css">.gm-control-active img{box-sizing:content-box;pointer-events:none}.gm-control-active:hover img:nth-child(1),.gm-control-active:active img:nth-child(1),.gm-control-active:active img:nth-child(2){display:none}\n</style><style type="text/css">.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}\n</style><style type="text/css">@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style type="text/css">.gm-ui-hover-effect{opacity:.7}.gm-ui-hover-effect:hover{opacity:1}\n</style><style type="text/css">.gm-style .gm-style-iw{font-weight:300;font-size:13px;overflow:hidden}.gm-style .gm-iw{color:#2c2c2c}.gm-style .gm-iw b{font-weight:400}.gm-style .gm-iw a:link,.gm-style .gm-iw a:visited{color:#4272db;text-decoration:none}.gm-style .gm-iw a:hover{color:#4272db;text-decoration:underline}
# ...

# %%
soup = BeautifulSoup(current_page_source, 'html.parser')

# %%
list_of_types = []
for each_type in soup.find_all('span', class_="Text Utils-accent-dark Text-tiny Text-xlAndUp-sm"):
    list_of_types.append(each_type.get_text())

# %%
list_of_types
# Out:
# ['Studio', '1 bed', '2 beds', '3+ beds']

# %%
list_of_prices = []
for each_price in soup.find_all('span', class_="Text FloorplanPricePreview-price Text-sm Text-xlAndUp-md"):
    list_of_prices.append(int(each_price.get_text().replace('$', '').replace(',', '').replace('+', '')))

# %%
list_of_prices
# Out:
# [1265, 1670, 1890, 3200]

# %%
list_of_building_types = []
for each_building_type in soup.find_all('h2', class_="Text PropertyTypeIcon-keyword Utils-accent-dark Text-sm Text-xlAndUp-md"):
    list_of_building_types.append(each_building_type.get_text())

# %%
list_of_building_types * len(list_of_types)
# Out:
# ['Apartment building',
#  'Apartment building',
#  'Apartment building',
#  'Apartment building']

# %%
list_of_building_types
# Out:
# ['Townhouse']
